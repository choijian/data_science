# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('medical_students_dataset.csv')

# %%
df.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
print('dataset의 총 길이 :',len(df))
# Out:
# dataset의 총 길이 : 200000

# %%
df.describe()
# Out:
#           Student ID            Age         Height         Weight  \
# count  180000.000000  180000.000000  180000.000000  180000.000000
# mean    49974.042078      26.021561     174.947103      69.971585
# std     28879.641657       4.890528      14.447560      17.322574
# min         1.000000      18.000000     150.000041      40.000578
# 25%     24971.750000      22.000000     162.476110      54.969838
# 50%     49943.500000      26.000000     174.899914      69.979384
# 75%     74986.000000      30.000000     187.464417      84.980097
# max    100000.000000      34.000000     199.998639      99.999907
#
#                  BMI    Temperature     Heart Rate  Blood Pressure  \
# count  180000.000000  180000.000000  180000.000000   180000.000000
# mean       23.338869      98.600948      79.503767      114.558033
# std         7.033554       0.500530      11.540755       14.403353
# min        10.074837      96.397835      60.000000       90.000000
# 25%        17.858396      98.264750      70.000000      102.000000
# 50%        22.671401      98.599654      80.000000      115.000000
# 75%        27.997487      98.940543      90.000000      127.000000
# max        44.355113     100.824857      99.000000      139.000000
#
#          Cholesterol
# count  180000.000000
# mean      184.486361
# std        37.559678
# min       120.000000
# 25%       152.000000
# 50%       184.000000
# 75%       217.000000
# max       249.000000

# %% [markdown]
# # 중복값 확인 및 제거

# %%
print("중복된 data개수 :", len(df[df.duplicated()]))
df[df.duplicated()]
# Out:
# 중복된 data개수 : 7644
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 100007         8.0  28.0    Male  186.489402  52.389752         AB  15.063921
# 100011        12.0  34.0  Female  182.416302  76.371050         AB  22.950992
# 100018        19.0  31.0  Female  158.790160  46.829849         AB  18.572723
# 100022        23.0  29.0  Female  179.909041  90.679436         AB  28.015787
# 100023        24.0  18.0    Male         NaN  52.521560         AB  13.570402
# ...            ...   ...     ...         ...        ...        ...        ...
# 199961     99962.0  31.0    Male  180.859321  43.647709          B  13.343804
# 199962     99963.0  18.0  Female  180.133710  48.381499          A  14.910401
# 199965     99966.0  22.0  Female  166.562901  48.684146         AB  17.548137
# 199973     99974.0  25.0  Female  156.297842  90.690186          B  37.123963
# 199985     99986.0  23.0  Female  162.884951  82.485778          B  31.089745
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 100007    98.227788        85.0           123.0        128.0       No      No
# 100011    98.118274        86.0            97.0        247.0       No      No
# 100018    98.784709        92.0           102.0        172.0      NaN      No
# 100022    98.782269        81.0           108.0        227.0       No     Yes
# 100023    98.215090        60.0           132.0        217.0       No      No
# ...             ...         ...             ...          ...      ...     ...
# 199961    98.675411        68.0            90.0        223.0       No      No
# 199962    98.104064        71.0           129.0        184.0       No      No
# 199965    98.776134        95.0           109.0        152.0      Yes      No
# 199973    98.664591        70.0           132.0        164.0      Yes      No
# 199985    98.852347        65.0            94.0        188.0       No     Yes
#
# [7644 rows x 13 columns]

# %%
# 중복값 제거
df = df.drop_duplicates()

# %%
print("중복값 제거 후 길이 :", len(df))
df[df.duplicated()]
# Out:
# 중복값 제거 후 길이 : 192356
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %%
df.describe()
# Out:
#           Student ID            Age         Height         Weight  \
# count  172465.000000  172464.000000  172449.000000  172455.000000
# mean    49981.974488      26.022254     174.958363      69.980827
# std     28886.214693       4.890591      14.451249      17.323637
# min         1.000000      18.000000     150.000041      40.000578
# 25%     24968.000000      22.000000     162.480748      54.973981
# 50%     49950.000000      26.000000     174.920345      69.995078
# 75%     75015.000000      30.000000     187.469633      84.988687
# max    100000.000000      34.000000     199.998639      99.999907
#
#                  BMI    Temperature     Heart Rate  Blood Pressure  \
# count  172456.000000  172445.000000  172453.000000   172464.000000
# mean       23.338982      98.601117      79.508817      114.564761
# std         7.033691       0.500216      11.543127       14.404302
# min        10.074837      96.397835      60.000000       90.000000
# 25%        17.858903      98.264992      70.000000      102.000000
# 50%        22.670746      98.599527      80.000000      115.000000
# 75%        27.992399      98.940488      90.000000      127.000000
# max        44.355113     100.824857      99.000000      139.000000
#
#          Cholesterol
# count  172463.000000
# mean      184.499765
# std        37.551044
# min       120.000000
# 25%       152.000000
# 50%       184.000000
# 75%       217.000000
# max       249.000000

# %% [markdown]
# # 이상치 확인 및 제거

# %%
# numerical feature들에 대해 이상치 확인 ('Height, Weight, Temperature, Heart Rate, Blood Pressure, Cholesterol)

numerical_features = ['Height', 'Weight', 'Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']

plt.figure(figsize=(10,10))

for i, col in enumerate(numerical_features):
    plt.subplot(3,2,i+1)
    sns.boxplot(x=df[col], color = 'darkviolet')

plt.show()

# %%
# IQR을 사용하여 이상치 제거
for col in numerical_features:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
# numerical feature들에 대해 이상치 확인 ('Height, Weight, Temperature, Heart Rate, Blood Pressure, Cholesterol)

numerical_features = ['Height', 'Weight', 'Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']

plt.figure(figsize=(20, 15))

for i, col in enumerate(numerical_features):
    plt.subplot(3,2,i+1)
    sns.boxplot(x=df[col], color = 'darkviolet')

plt.show()

# %%
print("이상치 제거 후 길이 : ", len(df))
# Out:
# 이상치 제거 후 길이 :  98503

# %% [markdown]
# # 결측치 확인 및 대체

# %%
df.isna().sum()
# Out:
# Student ID        10489
# Age               10478
# Gender            10500
# Height                0
# Weight                0
# Blood Type        10516
# BMI               10528
# Temperature           0
# Heart Rate            0
# Blood Pressure        0
# Cholesterol           0
# Diabetes          10456
# Smoking           10395
# dtype: int64

# %% [markdown]
# ## 결측치들을 채워주기 전에 각 변수들 간의 상관관계 분석

# %%
# corr를 계산하기 위해 Diabetes','Smoking'을 각각 0,1로 binarization
def binarize(value):
    if value == 'Yes':
        return 1
    else:
        return 0
    
df['Diabetes'] = df['Diabetes'].apply(binarize)
df['Smoking'] = df['Smoking'].apply(binarize)
df[['Diabetes', 'Smoking']]
# Out:
#         Diabetes  Smoking
# 1              0        0
# 2              1        0
# 3              0        1
# 5              0        1
# 6              0        0
# ...          ...      ...
# 199992         0        0
# 199995         0        0
# 199996         0        1
# 199998         0        0
# 199999         0        0
#
# [98503 rows x 2 columns]

# %%
plt.figure(figsize=(10,10))
# Student ID를 제외한 feature들끼리 상관관계 분석
sns.heatmap(df.corr(), annot=True, fmt=".4f", cmap='Blues')
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_13960\2780822343.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, fmt=".4f", cmap='Blues')

# %%
# 각 변수들 간의 상관관계가 유의미하지 않으므로 Numerical 결측치들은 각 feature의 중앙값으로 대체
numerical_features = ['Age','Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']

for col in numerical_features:
    df[col] =  df[col].fillna(df[col].median())
    print(f'median of {col} = ',df[col].median())
# Out:
# median of Age =  26.0
# median of Temperature =  98.59879600603593
# median of Heart Rate =  79.0
# median of Blood Pressure =  115.0
# median of Cholesterol =  184.0

# %%
df[numerical_features]
# Out:
#          Age  Temperature  Heart Rate  Blood Pressure  Cholesterol
# 1       26.0    98.714977        93.0           104.0        163.0
# 2       32.0    98.260293        76.0           130.0        216.0
# 3       30.0    98.839605        99.0           112.0        141.0
# 5       32.0    99.668373        70.0           128.0        183.0
# 6       21.0    97.715469        66.0           134.0        247.0
# ...      ...          ...         ...             ...          ...
# 199992  34.0    98.728836        70.0            96.0        208.0
# 199995  24.0    99.170685        65.0           121.0        130.0
# 199996  29.0    97.865785        62.0           125.0        198.0
# 199998  30.0    98.994212        61.0           106.0        225.0
# 199999  20.0    98.595817        95.0           133.0        132.0
#
# [98503 rows x 5 columns]

# %% [markdown]
# ### 키와 체중이 성별에 영향을 받는지 확인

# %%
df.groupby('Gender')['Weight'].describe()
# Out:
#           count       mean        std        min        25%        50%  \
# Gender
# Female  44020.0  69.930793  17.282742  40.000718  54.958293  69.917237
# Male    43983.0  69.996483  17.368336  40.000578  54.874695  70.040913
#
#               75%        max
# Gender
# Female  84.878932  99.998725
# Male    85.109781  99.999460

# %%
df.groupby('Gender')['Height'].describe()
# Out:
#           count        mean        std         min         25%         50%  \
# Gender
# Female  44020.0  174.941216  14.465672  150.000876  162.484518  174.903479
# Male    43983.0  175.025893  14.440688  150.000996  162.536600  174.986910
#
#                75%         max
# Gender
# Female  187.424780  199.996834
# Male    187.607102  199.998639

# %%
#키와 체중 분포가 성별과 관련없이 유사하므로 중앙값으로 대체
height_weight = ['Height', 'Weight']

for col in height_weight:
    df[col] =  df[col].fillna(df[col].median())
    print(f'median of {col} = ',df[col].median())
# Out:
# median of Height =  174.98149185250998
# median of Weight =  69.98918734627891

# %% [markdown]
# ## 수치상으로 대체하기 어려운 feature가 포함된 data들은 제거

# %%
cannot_replaceable_features = ['Age', 'Gender' ,'Blood Type', 'Diabetes', 'Smoking']

# %%
# 결측치가 있는 행 삭제
for feature in cannot_replaceable_features:
    df = df.dropna(subset=[feature])

# %%
len(df)
# Out:
# 78617

# %% [markdown]
# ## 'Student ID'와 'BMI' 재할당

# %%
df.isnull().sum()
# Out:
# Student ID        8511
# Age                  0
# Gender               0
# Height               0
# Weight               0
# Blood Type           0
# BMI               8494
# Temperature          0
# Heart Rate           0
# Blood Pressure       0
# Cholesterol          0
# Diabetes             0
# Smoking              0
# dtype: int64

# %%
# Height와 Weight 기반으로 'BMI' 재계산
df['BMI'] = (df['Weight'] / pow(df['Height'], 2)) * 10000

# %%
# index 기반으로 'Student ID' 재할당
df['Student ID'] = np.arange(1, len(df) + 1, dtype='float64')

# %%
# 결측치 유무 확인
df.isnull().sum()
# Out:
# Student ID        0
# Age               0
# Gender            0
# Height            0
# Weight            0
# Blood Type        0
# BMI               0
# Temperature       0
# Heart Rate        0
# Blood Pressure    0
# Cholesterol       0
# Diabetes          0
# Smoking           0
# dtype: int64

# %%
# 중복값 유무 확인
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Student ID, Age, Gender, Height, Weight, Blood Type, BMI, Temperature, Heart Rate, Blood Pressure, Cholesterol, Diabetes, Smoking]
# Index: []

# %%
# binarization 되었던 'Diabetes','Smoking'을 각각 'Yes', 'No'로 재할당
def binarize(value):
    if value == 1:
        return 'Yes'
    else:
        return 'No'
    
df['Diabetes'] = df['Diabetes'].apply(binarize)
df['Smoking'] = df['Smoking'].apply(binarize)
df[['Diabetes', 'Smoking']]
# Out:
#        Diabetes Smoking
# 1            No      No
# 2           Yes      No
# 3            No     Yes
# 7            No      No
# 11           No      No
# ...         ...     ...
# 199990       No     Yes
# 199992       No      No
# 199995       No      No
# 199998       No      No
# 199999       No      No
#
# [78617 rows x 2 columns]

# %%
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 1              1.0  26.0    Male  152.069157  47.630941          B  20.597139
# 2              2.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              3.0  30.0    Male  182.112867  63.332207          B  19.096042
# 7              4.0  28.0    Male  186.489402  52.389752         AB  15.063921
# 11             5.0  34.0  Female  182.416302  76.371050         AB  22.950992
# ...            ...   ...     ...         ...        ...        ...        ...
# 199990     78613.0  21.0  Female  183.735110  51.172076         AB  15.158238
# 199992     78614.0  34.0    Male  161.590030  90.877589          B  34.803881
# 199995     78615.0  24.0    Male  176.503260  95.756997          B  30.737254
# 199998     78616.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999     78617.0  20.0  Female  153.927409  99.928405          O  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 1         98.714977        93.0           104.0        163.0       No      No
# 2         98.260293        76.0           130.0        216.0      Yes      No
# 3         98.839605        99.0           112.0        141.0       No     Yes
# 7         98.227788        85.0           123.0        128.0       No      No
# 11        98.118274        86.0            97.0        247.0       No      No
# ...             ...         ...             ...          ...      ...     ...
# 199990    97.998790        67.0            96.0        249.0       No     Yes
# 199992    98.728836        70.0            96.0        208.0       No      No
# 199995    99.170685        65.0           121.0        130.0       No      No
# 199998    98.994212        61.0           106.0        225.0       No      No
# 199999    98.595817        95.0           133.0        132.0       No      No
#
# [78617 rows x 13 columns]

# %%
# 최종 결과 반환
df.to_csv('result.csv', index=False)
